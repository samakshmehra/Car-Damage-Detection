# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="eOHkgfbMs0GzMvv1zyuH")
project = rf.workspace("sindhu").project("car_dent_scratch_detection-1")
version = project.version(9)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 134.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Car_Dent_Scratch_Detection(1)-9 in yolov8:: 100%|██████████| 6152/6152 [00:00<00:00, 6870.55it/s]

# %%
# !pip install matplotlib numpy opencv-python pillow psutil PyYAML requests scipy thop torch torchvision tqdm ultralytics pandas seaborn setuptools filterpy scikit-image lap
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 7.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 86.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 49.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 35.9 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
from ultralytics import YOLO

# Mount Google Drive
drive.mount('/content/drive')

# Define the model (e.g., yolov8l.pt for large model)
model = YOLO('yolov8l.pt')  # This loads the yolov8l model

# Save the model path in Google Drive
model_save_path = '/content/drive/MyDrive/yolov8_model.pt'

# Train the model
model.train(
    data="/content/Car_Dent_Scratch_Detection(1)-9/data.yaml",  # ✅ actual path
    epochs=50,
    imgsz=640,
    batch=8,
    workers=2,
    device=0  # Ensure you're using the GPU (0 means GPU 0)
)

# Save the model after training
model.save(model_save_path)

print(f"Model saved to {model_save_path}")

# To load the model after reconnection:
# model = YOLO(model_save_path)  # Load the model from Google Drive
# Out:
# Mounted at /content/drive
# ...
# 100%|██████████| 83.7M/83.7M [00:00<00:00, 113MB/s]
# Ultralytics 8.3.124 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !pip install opencv-python cvzone ultralytics
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for cvzone: filename=cvzone-1.6.1-py3-none-any.whl size=26298 sha256=24c9e0fb88c10b8b3c86a51dc27e20cf8f433aab9464f45d831557d7d5592c0a
#   Stored in directory: /root/.cache/pip/wheels/ab/36/ec/47be2d4e59dc4289e684d5b0dde54d1e72e51a614e57690e85
# Successfully built cvzone
# ...

# %%
from ultralytics import YOLO

# Load YOLO model with custom weights from Google Drive
yolo_model = YOLO("/content/drive/MyDrive/yolov8_model.pt")

# Define class names
class_labels = [
    'Bodypanel-Dent', 'Front-Windscreen-Damage', 'Headlight-Damage',
    'Rear-windscreen-Damage', 'RunningBoard-Dent', 'Sidemirror-Damage',
    'Signlight-Damage', 'Taillight-Damage', 'bonnet-dent', 'boot-dent',
    'doorouter-dent', 'fender-dent', 'front-bumper-dent', 'pillar-dent',
    'quaterpanel-dent', 'rear-bumper-dent', 'roof-dent'
]

# %%
# Load the image
image_path = "/content/rivernorthcollisionrepair-291853-dented-white-bumper-blogbanner1.jpg"
img = cv2.imread(image_path)

# %%
# Perform object detection
results = yolo_model(img)
# Out:
# 0: 448x640 1 front-bumper-dent, 50.0ms
# Speed: 6.3ms preprocess, 50.0ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)

# %%
# !pip install cvzone
import cvzone

# %%
from google.colab.patches import cv2_imshow

# Display the image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1280>
